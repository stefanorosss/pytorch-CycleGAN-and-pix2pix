# %%
import json
import sagemaker
import os
from s3_conx import *
from sagemaker.pytorch import PyTorch

def iterate_to_s3(path):
    if os.path.isdir(path):
        for _dir in os.listdir(path):
            iterate_to_s3(path+_dir)
    else:
        s3.upload_file_to_s3(path)
    return

if __name__ == '__main__':
    # Initializes SageMaker session which holds context data
    sagemaker_session = sagemaker.Session()
    role = sagemaker_session.get_caller_identity_arn()
    
    local_path = 'checkpoints'
    estimator = PyTorch(
      # name of the runnable script containing __main__ function (entrypoint)
      entry_point='train.py',
      # path of the folder containing training code. It could also contain a
      # requirements.txt file with all the dependencies that needs
      # to be installed before running
      source_dir='.',
      framework_version='1.5.0',
      train_instance_count=1,
      train_instance_type='ml.p2.xlarge',
       #train_instance_type='ml.m4.xlarge', 
      role=role,
        checkpoint_local_path = local_path+'/',
      # these hyperparameters are passed to the main script as arguments and 
      # can be overridden when fine tuning the algorithm
      hyperparameters={
      'n_epochs': 10 ,
          'n_epochs_decay': 0,
          'lr':0.0002,
          'dataroot':'datasets/olracle/train',
          'checkpoints_dir':'checkpoints',
          'name':'olracle-pix2pix',
          'model':'pix2pix',
          'print_freq':480,
          'display_freq':480,
          'input_nc':1,
          'output_nc':1,
          'num_threads':0,
          'dataset_mode':'aligned',
          'save_epoch_freq':50,
      'batch_size': 4,
      })
    estimator.fit()
# Out:
# 'create_image_uri' will be deprecated in favor of 'ImageURIProvider' class in SageMaker Python SDK v2.
# 'create_image_uri' will be deprecated in favor of 'ImageURIProvider' class in SageMaker Python SDK v2.
# 2020-11-18 16:58:01 Starting - Starting the training job...
# 2020-11-18 16:58:04 Starting - Launching requested ML instances......
# 2020-11-18 16:59:09 Starting - Preparing the instances for training.........
# 2020-11-18 17:00:35 Downloading - Downloading input data...
# 2020-11-18 17:01:26 Training - Downloading the training image.........
# 2020-11-18 17:03:04 Training - Training image download completed. Training in progress..bash: cannot set terminal process group (-1): Inappropriate ioctl for device
# bash: no job control in this shell
# 2020-11-18 17:03:05,525 sagemaker-containers INFO     Imported framework sagemaker_pytorch_container.training
# 2020-11-18 17:03:05,551 sagemaker_pytorch_container.training INFO     Block until all host DNS lookups succeed.
# 2020-11-18 17:03:05,554 sagemaker_pytorch_container.training INFO     Invoking user training script.
# 2020-11-18 17:03:07,596 sagemaker-containers INFO     Module default_user_module_name does not provide a setup.py.
# Generating setup.py
# 2020-11-18 17:03:07,597 sagemaker-containers INFO     Generating setup.cfg
# 2020-11-18 17:03:07,597 sagemaker-containers INFO     Generating MANIFEST.in
# 2020-11-18 17:03:07,597 sagemaker-containers INFO     Installing module with the following command:
# /opt/conda/bin/python -m pip install . -r requirements.txt
# Processing /tmp/tmpum3ybw3i/module_dir
# Requirement already satisfied: torch>=0.4.1 in /opt/conda/lib/python3.6/site-packages (from -r requirements.txt (line 1)) (1.5.0)
# Requirement already satisfied: torchvision>=0.2.1 in /opt/conda/lib/python3.6/site-packages (from -r requirements.txt (line 2)) (0.6.0)
# Collecting dominate>=2.3.1
#   Downloading dominate-2.6.0-py2.py3-none-any.whl (29 kB)
# Collecting visdom>=0.1.8.3
#   Downloading visdom-0.1.8.9.tar.gz (676 kB)
# Requirement already satisfied: future in /opt/conda/lib/python3.6/site-packages (from torch>=0.4.1->-r requirements.txt (line 1)) (0.17.1)
# Requirement already satisfied: numpy in /opt/conda/lib/python3.6/site-packages (from torch>=0.4.1->-r requirements.txt (line 1)) (1.16.4)
# Requirement already satisfied: pillow>=4.1.1 in /opt/conda/lib/python3.6/site-packages (from torchvision>=0.2.1->-r requirements.txt (line 2)) (7.1.0)
# Requirement already satisfied: scipy in /opt/conda/lib/python3.6/site-packages (from visdom>=0.1.8.3->-r requirements.txt (line 4)) (1.2.2)
# Requirement already satisfied: requests in /opt/conda/lib/python3.6/site-packages (from visdom>=0.1.8.3->-r requirements.txt (line 4)) (2.22.0)
# Collecting tornado
#   Downloading tornado-6.1-cp36-cp36m-manylinux2010_x86_64.whl (427 kB)
# Collecting pyzmq
#   Downloading pyzmq-20.0.0-cp36-cp36m-manylinux1_x86_64.whl (1.1 MB)
# Requirement already satisfied: six in /opt/conda/lib/python3.6/site-packages (from visdom>=0.1.8.3->-r requirements.txt (line 4)) (1.14.0)
# Collecting jsonpatch
#   Downloading jsonpatch-1.26-py2.py3-none-any.whl (11 kB)
# Collecting torchfile
#   Downloading torchfile-0.1.0.tar.gz (5.2 kB)
# Collecting websocket-client
#   Downloading websocket_client-0.57.0-py2.py3-none-any.whl (200 kB)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /opt/conda/lib/python3.6/site-packages (from requests->visdom>=0.1.8.3->-r requirements.txt (line 4)) (1.25.8)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/conda/lib/python3.6/site-packages (from requests->visdom>=0.1.8.3->-r requirements.txt (line 4)) (2020.4.5.1)
# Requirement already satisfied: idna<2.9,>=2.5 in /opt/conda/lib/python3.6/site-packages (from requests->visdom>=0.1.8.3->-r requirements.txt (line 4)) (2.8)
# Requirement already satisfied: chardet<3.1.0,>=3.0.2 in /opt/conda/lib/python3.6/site-packages (from requests->visdom>=0.1.8.3->-r requirements.txt (line 4)) (3.0.4)
# Collecting jsonpointer>=1.9
#   Downloading jsonpointer-2.0-py2.py3-none-any.whl (7.6 kB)
# Building wheels for collected packages: visdom, default-user-module-name, torchfile
#   Building wheel for visdom (setup.py): started
#   Building wheel for visdom (setup.py): finished with status 'done'
#   Created wheel for visdom: filename=visdom-0.1.8.9-py3-none-any.whl size=655249 sha256=f038e2197cd2894fbbf53b51a753b5b48c034ab484fe7a5e468f374805dba28c
#   Stored in directory: /root/.cache/pip/wheels/2d/cd/fb/005445070865d4e45365b2946ee88085a7392370f152cf371c
#   Building wheel for default-user-module-name (setup.py): started
#   Building wheel for default-user-module-name (setup.py): finished with status 'done'
#   Created wheel for default-user-module-name: filename=default_user_module_name-1.0.0-py2.py3-none-any.whl size=77121203 sha256=109f2a05c7a1a613f138ff83994ff9fc141752eff072f9f5552cd076b912aa44
#   Stored in directory: /tmp/pip-ephem-wheel-cache-y6ixrt14/wheels/b0/8a/c1/cffc10603ef46276dfc72908c6f6736990f46665f774afe838
#   Building wheel for torchfile (setup.py): started
#   Building wheel for torchfile (setup.py): finished with status 'done'
#   Created wheel for torchfile: filename=torchfile-0.1.0-py3-none-any.whl size=5711 sha256=946e9582e7e5a276824e9df961c6aeb182986a6cdd4fb9d7b63ef0683f50e9a3
#   Stored in directory: /root/.cache/pip/wheels/55/79/ec/084a3a2e348d72852cc0c13c559c923c13ca54db86e699b681
# Successfully built visdom default-user-module-name torchfile
# Installing collected packages: dominate, tornado, pyzmq, jsonpointer, jsonpatch, torchfile, websocket-client, visdom, default-user-module-name
# Successfully installed default-user-module-name-1.0.0 dominate-2.6.0 jsonpatch-1.26 jsonpointer-2.0 pyzmq-20.0.0 torchfile-0.1.0 tornado-6.1 visdom-0.1.8.9 websocket-client-0.57.0
# WARNING: You are using pip version 20.1; however, version 20.2.4 is available.
# You should consider upgrading via the '/opt/conda/bin/python -m pip install --upgrade pip' command.
# 2020-11-18 17:03:25,656 sagemaker-containers INFO     Invoking user script
#
# Training Env:
#
# {
#     "additional_framework_parameters": {},
#     "channel_input_dirs": {},
#     "current_host": "algo-1",
#     "framework_module": "sagemaker_pytorch_container.training:main",
#     "hosts": [
#         "algo-1"
#     ],
#     "hyperparameters": {
#         "checkpoints_dir": "checkpoints",
#         "batch_size": 4,
#         "input_nc": 1,
#         "n_epochs_decay": 1000,
#         "lr": 0.0002,
#         "print_freq": 480,
#         "n_epochs": 200,
#         "dataset_mode": "aligned",
#         "display_freq": 480,
#         "name": "olracle-pix2pix",
#         "num_threads": 0,
#         "model": "pix2pix",
#         "dataroot": "datasets/olracle/train",
#         "save_epoch_freq": 50,
#         "output_nc": 1
#     },
#     "input_config_dir": "/opt/ml/input/config",
#     "input_data_config": {},
#     "input_dir": "/opt/ml/input",
#     "is_master": true,
#     "job_name": "pytorch-training-2020-11-18-16-57-55-858",
#     "log_level": 20,
#     "master_hostname": "algo-1",
#     "model_dir": "/opt/ml/model",
#     "module_dir": "s3://sagemaker-eu-central-1-213183576773/pytorch-training-2020-11-18-16-57-55-858/source/sourcedir.tar.gz",
#     "module_name": "train",
#     "network_interface_name": "eth0",
#     "num_cpus": 4,
#     "num_gpus": 1,
#     "output_data_dir": "/opt/ml/output/data",
#     "output_dir": "/opt/ml/output",
#     "output_intermediate_dir": "/opt/ml/output/intermediate",
#     "resource_config": {
#         "current_host": "algo-1",
#         "hosts": [
#             "algo-1"
#         ],
#         "network_interface_name": "eth0"
#     },
#     "user_entry_point": "train.py"
# }
#
# Environment variables:
#
# SM_HOSTS=["algo-1"]
# SM_NETWORK_INTERFACE_NAME=eth0
# SM_HPS={"batch_size":4,"checkpoints_dir":"checkpoints","dataroot":"datasets/olracle/train","dataset_mode":"aligned","display_freq":480,"input_nc":1,"lr":0.0002,"model":"pix2pix","n_epochs":200,"n_epochs_decay":1000,"name":"olracle-pix2pix","num_threads":0,"output_nc":1,"print_freq":480,"save_epoch_freq":50}
# SM_USER_ENTRY_POINT=train.py
# SM_FRAMEWORK_PARAMS={}
# SM_RESOURCE_CONFIG={"current_host":"algo-1","hosts":["algo-1"],"network_interface_name":"eth0"}
# SM_INPUT_DATA_CONFIG={}
# SM_OUTPUT_DATA_DIR=/opt/ml/output/data
# SM_CHANNELS=[]
# SM_CURRENT_HOST=algo-1
# SM_MODULE_NAME=train
# SM_LOG_LEVEL=20
# SM_FRAMEWORK_MODULE=sagemaker_pytorch_container.training:main
# SM_INPUT_DIR=/opt/ml/input
# SM_INPUT_CONFIG_DIR=/opt/ml/input/config
# SM_OUTPUT_DIR=/opt/ml/output
# SM_NUM_CPUS=4
# SM_NUM_GPUS=1
# SM_MODEL_DIR=/opt/ml/model
# SM_MODULE_DIR=s3://sagemaker-eu-central-1-213183576773/pytorch-training-2020-11-18-16-57-55-858/source/sourcedir.tar.gz
# SM_TRAINING_ENV={"additional_framework_parameters":{},"channel_input_dirs":{},"current_host":"algo-1","framework_module":"sagemaker_pytorch_container.training:main","hosts":["algo-1"],"hyperparameters":{"batch_size":4,"checkpoints_dir":"checkpoints","dataroot":"datasets/olracle/train","dataset_mode":"aligned","display_freq":480,"input_nc":1,"lr":0.0002,"model":"pix2pix","n_epochs":200,"n_epochs_decay":1000,"name":"olracle-pix2pix","num_threads":0,"output_nc":1,"print_freq":480,"save_epoch_freq":50},"input_config_dir":"/opt/ml/input/config","input_data_config":{},"input_dir":"/opt/ml/input","is_master":true,"job_name":"pytorch-training-2020-11-18-16-57-55-858","log_level":20,"master_hostname":"algo-1","model_dir":"/opt/ml/model","module_dir":"s3://sagemaker-eu-central-1-213183576773/pytorch-training-2020-11-18-16-57-55-858/source/sourcedir.tar.gz","module_name":"train","network_interface_name":"eth0","num_cpus":4,"num_gpus":1,"output_data_dir":"/opt/ml/output/data","output_dir":"/opt/ml/output","output_intermediate_dir":"/opt/ml/output/intermediate","resource_config":{"current_host":"algo-1","hosts":["algo-1"],"network_interface_name":"eth0"},"user_entry_point":"train.py"}
# SM_USER_ARGS=["--batch_size","4","--checkpoints_dir","checkpoints","--dataroot","datasets/olracle/train","--dataset_mode","aligned","--display_freq","480","--input_nc","1","--lr","0.0002","--model","pix2pix","--n_epochs","200","--n_epochs_decay","1000","--name","olracle-pix2pix","--num_threads","0","--output_nc","1","--print_freq","480","--save_epoch_freq","50"]
# SM_OUTPUT_INTERMEDIATE_DIR=/opt/ml/output/intermediate
# SM_HP_CHECKPOINTS_DIR=checkpoints
# SM_HP_BATCH_SIZE=4
# SM_HP_INPUT_NC=1
# SM_HP_N_EPOCHS_DECAY=1000
# SM_HP_LR=0.0002
# SM_HP_PRINT_FREQ=480
# SM_HP_N_EPOCHS=200
# SM_HP_DATASET_MODE=aligned
# SM_HP_DISPLAY_FREQ=480
# SM_HP_NAME=olracle-pix2pix
# SM_HP_NUM_THREADS=0
# SM_HP_MODEL=pix2pix
# SM_HP_DATAROOT=datasets/olracle/train
# SM_HP_SAVE_EPOCH_FREQ=50
# SM_HP_OUTPUT_NC=1
# PYTHONPATH=/opt/ml/code:/opt/conda/bin:/opt/conda/lib/python36.zip:/opt/conda/lib/python3.6:/opt/conda/lib/python3.6/lib-dynload:/opt/conda/lib/python3.6/site-packages
#
# Invoking script with the following command:
#
# /opt/conda/bin/python train.py --batch_size 4 --checkpoints_dir checkpoints --dataroot datasets/olracle/train --dataset_mode aligned --display_freq 480 --input_nc 1 --lr 0.0002 --model pix2pix --n_epochs 200 --n_epochs_decay 1000 --name olracle-pix2pix --num_threads 0 --output_nc 1 --print_freq 480 --save_epoch_freq 50
#
#
# ----------------- Options ---------------
#                batch_size: 4                             #011[default: 1]
#                     beta1: 0.5
#           checkpoints_dir: checkpoints                   #011[default: ./checkpoints]
#            continue_train: False
#                 crop_size: 256
#                  dataroot: datasets/olracle/train        #011[default: None]
#              dataset_mode: aligned
#                 direction: AtoB
#               display_env: main
#              display_freq: 480                           #011[default: 400]
#                display_id: 1
#             display_ncols: 4
#              display_port: 8097
#            display_server: http://localhost
#           display_winsize: 256
#                     epoch: latest
#               epoch_count: 1
#                  gan_mode: vanilla
#                   gpu_ids: 0
#                 init_gain: 0.02
#                 init_type: normal
#                  input_nc: 1                             #011[default: 3]
#                   isTrain: True                          #011[default: None]
#                 lambda_L1: 100.0
#                 load_iter: 0                             #011[default: 0]
#                 load_size: 286
#                        lr: 0.0002
#            lr_decay_iters: 50
#                 lr_policy: linear
#          max_dataset_size: inf
#                     model: pix2pix                       #011[default: cycle_gan]
#                  n_epochs: 200                           #011[default: 100]
#            n_epochs_decay: 1000                          #011[default: 100]
#                n_layers_D: 3
#                      name: olracle-pix2pix               #011[default: experiment_name]
#                       ndf: 64
#                      netD: basic
#                      netG: unet_256
#                       ngf: 64
#                no_dropout: False
#                   no_flip: False
#                   no_html: False
#                      norm: batch
#               num_threads: 0                             #011[default: 4]
#                 output_nc: 1                             #011[default: 3]
#                     phase: train
#                 pool_size: 0
#                preprocess: resize_and_crop
#                print_freq: 480                           #011[default: 100]
#              save_by_iter: False
#           save_epoch_freq: 50                            #011[default: 5]
#          save_latest_freq: 5000
#            serial_batches: False
#                    suffix:
#          update_html_freq: 1000
#                   verbose: False
# ----------------- End -------------------
# dataset [AlignedDataset] was created
# Job Id = 1605719007
# The number of training images = 480
# initialize network with normal
# initialize network with normal
# model [Pix2PixModel] was created
# ---------- Networks initialized -------------
# [Network G] Total number of parameters : 54.408 M
# [Network D] Total number of parameters : 2.765 M
# -----------------------------------------------
# Exception in user code:
# ------------------------------------------------------------
# Could not connect to Visdom server.
#  Trying to start a server....
# Command: /opt/conda/bin/python -m visdom.server -p 8097 &>/dev/null &
# create web directory checkpoints/olracle-pix2pix/web...
# [2020-11-18 17:03:36.433 algo-1:81 INFO json_config.py:90] Creating hook from json_config at /opt/ml/input/config/debughookconfig.json.
# [2020-11-18 17:03:36.434 algo-1:81 INFO hook.py:183] tensorboard_dir has not been set for the hook. SMDebug will not be exporting tensorboard summaries.
# [2020-11-18 17:03:36.434 algo-1:81 INFO hook.py:228] Saving to /opt/ml/output/tensors
# [2020-11-18 17:03:36.461 algo-1:81 INFO hook.py:364] Monitoring the collections: losses
# [2020-11-18 17:03:36.461 algo-1:81 INFO hook.py:422] Hook is writing from the hook with pid: 81
#
# (epoch: 1, iters: 480, time: 0.167, data: 0.068) G_GAN: 1.459 G_L1: 21.697 D_real: 0.318 D_fake: 0.201
# End of epoch 1 / 1200 #011 Time Taken: 44 sec
# learning rate = 0.0002000
# (epoch: 2, iters: 480, time: 0.167, data: 0.024) G_GAN: 2.998 G_L1: 22.144 D_real: 0.091 D_fake: 0.060
# End of epoch 2 / 1200 #011 Time Taken: 37 sec
# learning rate = 0.0002000
# (epoch: 3, iters: 480, time: 0.166, data: 0.028) G_GAN: 1.502 G_L1: 24.350 D_real: 0.390 D_fake: 0.168
# End of epoch 3 / 1200 #011 Time Taken: 38 sec
# learning rate = 0.0002000
# (epoch: 4, iters: 480, time: 0.166, data: 0.027) G_GAN: 1.889 G_L1: 15.940 D_real: 0.265 D_fake: 0.109
# End of epoch 4 / 1200 #011 Time Taken: 38 sec
# learning rate = 0.0002000
# (epoch: 5, iters: 480, time: 0.168, data: 0.029) G_GAN: 1.922 G_L1: 17.770 D_real: 0.321 D_fake: 0.287
# End of epoch 5 / 1200 #011 Time Taken: 38 sec
# learning rate = 0.0002000
# (epoch: 6, iters: 480, time: 0.169, data: 0.024) G_GAN: 1.703 G_L1: 18.443 D_real: 0.173 D_fake: 0.435
# End of epoch 6 / 1200 #011 Time Taken: 38 sec
# learning rate = 0.0002000
# (epoch: 7, iters: 480, time: 0.169, data: 0.024) G_GAN: 1.725 G_L1: 17.188 D_real: 0.650 D_fake: 0.075
# End of epoch 7 / 1200 #011 Time Taken: 38 sec
# learning rate = 0.0002000
# (epoch: 8, iters: 480, time: 0.165, data: 0.024) G_GAN: 1.174 G_L1: 15.980 D_real: 0.367 D_fake: 0.502
# End of epoch 8 / 1200 #011 Time Taken: 38 sec
# learning rate = 0.0002000
# (epoch: 9, iters: 480, time: 0.171, data: 0.031) G_GAN: 2.676 G_L1: 21.745 D_real: 0.028 D_fake: 0.545
# End of epoch 9 / 1200 #011 Time Taken: 38 sec
# learning rate = 0.0002000
# (epoch: 10, iters: 480, time: 0.169, data: 0.024) G_GAN: 1.303 G_L1: 18.373 D_real: 0.082 D_fake: 0.299
# End of epoch 10 / 1200 #011 Time Taken: 38 sec
# learning rate = 0.0002000
# saving the latest model (epoch 11, total_iters 5000)
# (epoch: 11, iters: 480, time: 0.170, data: 0.024) G_GAN: 2.298 G_L1: 20.870 D_real: 0.166 D_fake: 0.272
# End of epoch 11 / 1200 #011 Time Taken: 39 sec
# learning rate = 0.0002000
# (epoch: 12, iters: 480, time: 0.169, data: 0.030) G_GAN: 3.101 G_L1: 22.169 D_real: 0.025 D_fake: 0.938
# End of epoch 12 / 1200 #011 Time Taken: 38 sec
# learning rate = 0.0002000
# (epoch: 13, iters: 480, time: 0.173, data: 0.030) G_GAN: 1.081 G_L1: 18.318 D_real: 0.461 D_fake: 0.135
# End of epoch 13 / 1200 #011 Time Taken: 38 sec
# learning rate = 0.0002000
# (epoch: 14, iters: 480, time: 0.173, data: 0.025) G_GAN: 1.383 G_L1: 16.618 D_real: 0.211 D_fake: 0.236
# End of epoch 14 / 1200 #011 Time Taken: 38 sec
# learning rate = 0.0002000
# (epoch: 15, iters: 480, time: 0.173, data: 0.025) G_GAN: 2.769 G_L1: 20.822 D_real: 0.167 D_fake: 0.085
# End of epoch 15 / 1200 #011 Time Taken: 38 sec
# learning rate = 0.0002000
# (epoch: 16, iters: 480, time: 0.175, data: 0.024) G_GAN: 2.090 G_L1: 19.955 D_real: 0.157 D_fake: 0.206
# End of epoch 16 / 1200 #011 Time Taken: 38 sec
# learning rate = 0.0002000
# (epoch: 17, iters: 480, time: 0.175, data: 0.024) G_GAN: 1.079 G_L1: 14.528 D_real: 0.707 D_fake: 0.070
# End of epoch 17 / 1200 #011 Time Taken: 38 sec
# learning rate = 0.0002000
# (epoch: 18, iters: 480, time: 0.176, data: 0.023) G_GAN: 2.873 G_L1: 23.851 D_real: 0.068 D_fake: 0.181
# End of epoch 18 / 1200 #011 Time Taken: 38 sec
# learning rate = 0.0002000
# (epoch: 19, iters: 480, time: 0.175, data: 0.024) G_GAN: 1.665 G_L1: 20.580 D_real: 0.563 D_fake: 0.089
# End of epoch 19 / 1200 #011 Time Taken: 38 sec
# learning rate = 0.0002000
# (epoch: 20, iters: 480, time: 0.177, data: 0.024) G_GAN: 3.131 G_L1: 24.140 D_real: 0.006 D_fake: 0.367
# End of epoch 20 / 1200 #011 Time Taken: 38 sec
# learning rate = 0.0002000
# saving the latest model (epoch 21, total_iters 10000)
# (epoch: 21, iters: 480, time: 0.177, data: 0.026) G_GAN: 2.585 G_L1: 18.084 D_real: 0.168 D_fake: 0.256
# End of epoch 21 / 1200 #011 Time Taken: 39 sec
# learning rate = 0.0002000
# (epoch: 22, iters: 480, time: 0.177, data: 0.030) G_GAN: 1.883 G_L1: 18.453 D_real: 1.406 D_fake: 0.011
# End of epoch 22 / 1200 #011 Time Taken: 38 sec
# learning rate = 0.0002000
# (epoch: 23, iters: 480, time: 0.178, data: 0.024) G_GAN: 2.369 G_L1: 15.344 D_real: 0.137 D_fake: 0.361
# End of epoch 23 / 1200 #011 Time Taken: 38 sec
# learning rate = 0.0002000
# (epoch: 24, iters: 480, time: 0.175, data: 0.030) G_GAN: 3.005 G_L1: 16.808 D_real: 0.038 D_fake: 0.153
# End of epoch 24 / 1200 #011 Time Taken: 38 sec
# learning rate = 0.0002000
# (epoch: 25, iters: 480, time: 0.182, data: 0.024) G_GAN: 2.552 G_L1: 14.624 D_real: 1.011 D_fake: 0.010
# End of epoch 25 / 1200 #011 Time Taken: 38 sec
# learning rate = 0.0002000
# (epoch: 26, iters: 480, time: 0.179, data: 0.024) G_GAN: 3.100 G_L1: 20.184 D_real: 0.010 D_fake: 0.184
# End of epoch 26 / 1200 #011 Time Taken: 38 sec
# learning rate = 0.0002000
# (epoch: 27, iters: 480, time: 0.180, data: 0.025) G_GAN: 4.355 G_L1: 16.757 D_real: 0.426 D_fake: 0.015
# End of epoch 27 / 1200 #011 Time Taken: 38 sec
# learning rate = 0.0002000
# (epoch: 28, iters: 480, time: 0.183, data: 0.024) G_GAN: 3.411 G_L1: 21.180 D_real: 0.005 D_fake: 0.123
# End of epoch 28 / 1200 #011 Time Taken: 38 sec
# learning rate = 0.0002000
# (epoch: 29, iters: 480, time: 0.184, data: 0.024) G_GAN: 1.060 G_L1: 17.355 D_real: 0.394 D_fake: 0.175
# End of epoch 29 / 1200 #011 Time Taken: 38 sec
# learning rate = 0.0002000
# (epoch: 30, iters: 480, time: 0.185, data: 0.025) G_GAN: 2.780 G_L1: 16.363 D_real: 0.012 D_fake: 0.117
# End of epoch 30 / 1200 #011 Time Taken: 38 sec
# learning rate = 0.0002000
# (epoch: 31, iters: 480, time: 0.183, data: 0.024) G_GAN: 2.440 G_L1: 19.149 D_real: 0.174 D_fake: 0.059
# End of epoch 31 / 1200 #011 Time Taken: 38 sec
# learning rate = 0.0002000
# saving the latest model (epoch 32, total_iters 15000)
# (epoch: 32, iters: 480, time: 0.185, data: 0.024) G_GAN: 1.624 G_L1: 16.727 D_real: 0.232 D_fake: 0.066
# End of epoch 32 / 1200 #011 Time Taken: 39 sec
# learning rate = 0.0002000
# (epoch: 33, iters: 480, time: 0.185, data: 0.025) G_GAN: 3.606 G_L1: 17.950 D_real: 0.012 D_fake: 0.866
# End of epoch 33 / 1200 #011 Time Taken: 38 sec
# learning rate = 0.0002000
# (epoch: 34, iters: 480, time: 0.185, data: 0.024) G_GAN: 2.601 G_L1: 20.391 D_real: 0.007 D_fake: 1.404
# End of epoch 34 / 1200 #011 Time Taken: 38 sec
# learning rate = 0.0002000
# (epoch: 35, iters: 480, time: 0.187, data: 0.025) G_GAN: 2.965 G_L1: 18.237 D_real: 0.008 D_fake: 0.175
# End of epoch 35 / 1200 #011 Time Taken: 38 sec
# learning rate = 0.0002000
# (epoch: 36, iters: 480, time: 0.186, data: 0.025) G_GAN: 0.421 G_L1: 18.073 D_real: 2.066 D_fake: 0.076
# End of epoch 36 / 1200 #011 Time Taken: 38 sec
# learning rate = 0.0002000
# (epoch: 37, iters: 480, time: 0.186, data: 0.029) G_GAN: 2.422 G_L1: 18.244 D_real: 0.213 D_fake: 0.093
# End of epoch 37 / 1200 #011 Time Taken: 38 sec
# learning rate = 0.0002000
# (epoch: 38, iters: 480, time: 0.190, data: 0.026) G_GAN: 2.998 G_L1: 21.143 D_real: 0.054 D_fake: 0.084
# End of epoch 38 / 1200 #011 Time Taken: 38 sec
# learning rate = 0.0002000
# (epoch: 39, iters: 480, time: 0.188, data: 0.024) G_GAN: 3.319 G_L1: 22.494 D_real: 0.032 D_fake: 0.080
# End of epoch 39 / 1200 #011 Time Taken: 38 sec
# learning rate = 0.0002000
# (epoch: 40, iters: 480, time: 0.191, data: 0.025) G_GAN: 2.973 G_L1: 17.327 D_real: 0.177 D_fake: 0.095
# End of epoch 40 / 1200 #011 Time Taken: 38 sec
# learning rate = 0.0002000
# (epoch: 41, iters: 480, time: 0.188, data: 0.030) G_GAN: 3.167 G_L1: 20.145 D_real: 0.043 D_fake: 0.042
# End of epoch 41 / 1200 #011 Time Taken: 38 sec
# learning rate = 0.0002000
# saving the latest model (epoch 42, total_iters 20000)
# (epoch: 42, iters: 480, time: 0.205, data: 0.030) G_GAN: 2.738 G_L1: 16.978 D_real: 0.067 D_fake: 0.172
# End of epoch 42 / 1200 #011 Time Taken: 39 sec
# learning rate = 0.0002000
# (epoch: 43, iters: 480, time: 0.191, data: 0.024) G_GAN: 2.396 G_L1: 14.769 D_real: 0.159 D_fake: 0.041
# End of epoch 43 / 1200 #011 Time Taken: 38 sec
# learning rate = 0.0002000
# (epoch: 44, iters: 480, time: 0.188, data: 0.024) G_GAN: 2.477 G_L1: 19.128 D_real: 0.001 D_fake: 1.674
# End of epoch 44 / 1200 #011 Time Taken: 38 sec
# learning rate = 0.0002000
# (epoch: 45, iters: 480, time: 0.193, data: 0.024) G_GAN: 4.519 G_L1: 17.382 D_real: 0.087 D_fake: 0.104
# End of epoch 45 / 1200 #011 Time Taken: 38 sec
# learning rate = 0.0002000
# (epoch: 46, iters: 480, time: 0.190, data: 0.024) G_GAN: 3.521 G_L1: 15.193 D_real: 0.269 D_fake: 0.018
# End of epoch 46 / 1200 #011 Time Taken: 38 sec
# learning rate = 0.0002000
# (epoch: 47, iters: 480, time: 0.191, data: 0.032) G_GAN: 2.573 G_L1: 17.188 D_real: 0.063 D_fake: 0.096
# End of epoch 47 / 1200 #011 Time Taken: 38 sec
# learning rate = 0.0002000
# (epoch: 48, iters: 480, time: 0.192, data: 0.030) G_GAN: 4.417 G_L1: 20.598 D_real: 0.076 D_fake: 0.022
# End of epoch 48 / 1200 #011 Time Taken: 38 sec
# learning rate = 0.0002000
# (epoch: 49, iters: 480, time: 0.195, data: 0.024) G_GAN: 3.634 G_L1: 15.888 D_real: 0.071 D_fake: 0.035
# End of epoch 49 / 1200 #011 Time Taken: 38 sec
# learning rate = 0.0002000
# (epoch: 50, iters: 480, time: 0.194, data: 0.025) G_GAN: 2.807 G_L1: 17.696 D_real: 0.017 D_fake: 0.272
# End of epoch 50 / 1200 #011 Time Taken: 38 sec
# learning rate = 0.0002000
