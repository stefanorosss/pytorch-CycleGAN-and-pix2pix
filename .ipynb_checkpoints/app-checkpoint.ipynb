# %%
import json
import sagemaker
import os
from s3_conx import *
from sagemaker.pytorch import PyTorch

def iterate_to_s3(path):
    if os.path.isdir(path):
        for _dir in os.listdir(path):
            iterate_to_s3(path+_dir)
    else:
        s3.upload_file_to_s3(path)
    return

if __name__ == '__main__':
    # Initializes SageMaker session which holds context data
    sagemaker_session = sagemaker.Session()
    role = sagemaker_session.get_caller_identity_arn()
    s3 = S3Con()
    local_path = 'checkpoints'
    estimator = PyTorch(
      # name of the runnable script containing __main__ function (entrypoint)
      entry_point='train.py',
      # path of the folder containing training code. It could also contain a
      # requirements.txt file with all the dependencies that needs
      # to be installed before running
      source_dir='.',
      framework_version='1.5.0',
      train_instance_count=1,
      train_instance_type='ml.m4.xlarge',
      role=role,
        checkpoint_local_path = local_path+'/',
      # these hyperparameters are passed to the main script as arguments and 
      # can be overridden when fine tuning the algorithm
      hyperparameters={
      'n_epochs': 1,
          'n_epochs_decay': 0,
          'lr':0.005,
          'dataroot':'datasets/olracle/train',
          'checkpoints_dir':'checkpoints',
          'name':'olracle-pix2pix',
          'model':'pix2pix',
          'print_freq':2,
          'dataset_mode':'aligned',
            'gpu_ids':-1,
      'batch_size': 60,
      })
    estimator.fit()
    for _dir in os.listdir(local_path):
        if os.path.isdir(local_path+'/'+_dir)
        s3.upload_file_to_s3()
# Out:
# 'create_image_uri' will be deprecated in favor of 'ImageURIProvider' class in SageMaker Python SDK v2.
# 'create_image_uri' will be deprecated in favor of 'ImageURIProvider' class in SageMaker Python SDK v2.
# 2020-11-16 14:35:18 Starting - Starting the training job...
# 2020-11-16 14:35:20 Starting - Launching requested ML instances......
# 2020-11-16 14:36:23 Starting - Preparing the instances for training...
# 2020-11-16 14:37:18 Downloading - Downloading input data...
# 2020-11-16 14:37:29 Training - Downloading the training image....bash: cannot set terminal process group (-1): Inappropriate ioctl for device
# bash: no job control in this shell
# 2020-11-16 14:38:21,945 sagemaker-containers INFO     Imported framework sagemaker_pytorch_container.training
# 2020-11-16 14:38:21,948 sagemaker-containers INFO     No GPUs detected (normal if no gpus installed)
# 2020-11-16 14:38:21,963 sagemaker_pytorch_container.training INFO     Block until all host DNS lookups succeed.
# 2020-11-16 14:38:24,987 sagemaker_pytorch_container.training INFO     Invoking user training script.
# 2020-11-16 14:38:26,045 sagemaker-containers INFO     Module default_user_module_name does not provide a setup.py.
# Generating setup.py
# 2020-11-16 14:38:26,046 sagemaker-containers INFO     Generating setup.cfg
# 2020-11-16 14:38:26,046 sagemaker-containers INFO     Generating MANIFEST.in
# 2020-11-16 14:38:26,046 sagemaker-containers INFO     Installing module with the following command:
# /opt/conda/bin/python -m pip install . -r requirements.txt
# Processing /tmp/tmpmcrqom47/module_dir
# Requirement already satisfied: torch>=0.4.1 in /opt/conda/lib/python3.6/site-packages (from -r requirements.txt (line 1)) (1.5.0)
# Requirement already satisfied: torchvision>=0.2.1 in /opt/conda/lib/python3.6/site-packages (from -r requirements.txt (line 2)) (0.6.0)
# Collecting dominate>=2.3.1
#   Downloading dominate-2.6.0-py2.py3-none-any.whl (29 kB)
# Collecting visdom>=0.1.8.3
#   Downloading visdom-0.1.8.9.tar.gz (676 kB)
# Requirement already satisfied: numpy in /opt/conda/lib/python3.6/site-packages (from torch>=0.4.1->-r requirements.txt (line 1)) (1.16.4)
# Requirement already satisfied: future in /opt/conda/lib/python3.6/site-packages (from torch>=0.4.1->-r requirements.txt (line 1)) (0.18.2)
# Requirement already satisfied: pillow>=4.1.1 in /opt/conda/lib/python3.6/site-packages (from torchvision>=0.2.1->-r requirements.txt (line 2)) (7.1.0)
# Requirement already satisfied: scipy in /opt/conda/lib/python3.6/site-packages (from visdom>=0.1.8.3->-r requirements.txt (line 4)) (1.2.2)
# Requirement already satisfied: requests in /opt/conda/lib/python3.6/site-packages (from visdom>=0.1.8.3->-r requirements.txt (line 4)) (2.22.0)
# Collecting tornado
#   Downloading tornado-6.1-cp36-cp36m-manylinux2010_x86_64.whl (427 kB)
# Collecting pyzmq
#   Downloading pyzmq-20.0.0-cp36-cp36m-manylinux1_x86_64.whl (1.1 MB)
# Requirement already satisfied: six in /opt/conda/lib/python3.6/site-packages (from visdom>=0.1.8.3->-r requirements.txt (line 4)) (1.14.0)
# Collecting jsonpatch
#   Downloading jsonpatch-1.26-py2.py3-none-any.whl (11 kB)
# Collecting torchfile
#   Downloading torchfile-0.1.0.tar.gz (5.2 kB)
# Collecting websocket-client
#   Downloading websocket_client-0.57.0-py2.py3-none-any.whl (200 kB)
# Requirement already satisfied: idna<2.9,>=2.5 in /opt/conda/lib/python3.6/site-packages (from requests->visdom>=0.1.8.3->-r requirements.txt (line 4)) (2.8)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/conda/lib/python3.6/site-packages (from requests->visdom>=0.1.8.3->-r requirements.txt (line 4)) (2020.4.5.1)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /opt/conda/lib/python3.6/site-packages (from requests->visdom>=0.1.8.3->-r requirements.txt (line 4)) (1.25.8)
# Requirement already satisfied: chardet<3.1.0,>=3.0.2 in /opt/conda/lib/python3.6/site-packages (from requests->visdom>=0.1.8.3->-r requirements.txt (line 4)) (3.0.4)
# Collecting jsonpointer>=1.9
#   Downloading jsonpointer-2.0-py2.py3-none-any.whl (7.6 kB)
# Building wheels for collected packages: visdom, default-user-module-name, torchfile
#   Building wheel for visdom (setup.py): started
#   Building wheel for visdom (setup.py): finished with status 'done'
#   Created wheel for visdom: filename=visdom-0.1.8.9-py3-none-any.whl size=655249 sha256=a77e1dc39643a19085740f6cc9114d9f2322de48fb37ea9874fb6a9b5489a27f
#   Stored in directory: /root/.cache/pip/wheels/2d/cd/fb/005445070865d4e45365b2946ee88085a7392370f152cf371c
#   Building wheel for default-user-module-name (setup.py): started
#   Building wheel for default-user-module-name (setup.py): finished with status 'done'
#   Created wheel for default-user-module-name: filename=default_user_module_name-1.0.0-py2.py3-none-any.whl size=37961412 sha256=b954201abdfd28cff187f00a05ad726e755b79064972a54c66d4108b0fce1456
#   Stored in directory: /tmp/pip-ephem-wheel-cache-ggxv04d8/wheels/5b/32/76/974df035c5d534ec6f9be68934139531405b4d4faa927bae86
#   Building wheel for torchfile (setup.py): started
#   Building wheel for torchfile (setup.py): finished with status 'done'
#   Created wheel for torchfile: filename=torchfile-0.1.0-py3-none-any.whl size=5711 sha256=216514deb12f7c2c3a1669cb752c67594da6c9abd44abc018e22ddc15e5a586c
#   Stored in directory: /root/.cache/pip/wheels/55/79/ec/084a3a2e348d72852cc0c13c559c923c13ca54db86e699b681
# Successfully built visdom default-user-module-name torchfile
# Installing collected packages: dominate, tornado, pyzmq, jsonpointer, jsonpatch, torchfile, websocket-client, visdom, default-user-module-name
# Successfully installed default-user-module-name-1.0.0 dominate-2.6.0 jsonpatch-1.26 jsonpointer-2.0 pyzmq-20.0.0 torchfile-0.1.0 tornado-6.1 visdom-0.1.8.9 websocket-client-0.57.0
# WARNING: You are using pip version 20.1; however, version 20.2.4 is available.
# You should consider upgrading via the '/opt/conda/bin/python -m pip install --upgrade pip' command.
# 2020-11-16 14:38:37,601 sagemaker-containers INFO     No GPUs detected (normal if no gpus installed)
# 2020-11-16 14:38:37,618 sagemaker-containers INFO     No GPUs detected (normal if no gpus installed)
# 2020-11-16 14:38:37,634 sagemaker-containers INFO     No GPUs detected (normal if no gpus installed)
# 2020-11-16 14:38:37,649 sagemaker-containers INFO     Invoking user script
#
# Training Env:
#
# {
#     "additional_framework_parameters": {},
#     "channel_input_dirs": {},
#     "current_host": "algo-1",
#     "framework_module": "sagemaker_pytorch_container.training:main",
#     "hosts": [
#         "algo-1"
#     ],
#     "hyperparameters": {
#         "checkpoints_dir": "checkpoints",
#         "batch_size": 60,
#         "n_epochs_decay": 0,
#         "lr": 0.005,
#         "print_freq": 2,
#         "n_epochs": 1,
#         "dataset_mode": "aligned",
#         "name": "olracle-pix2pix",
#         "model": "pix2pix",
#         "gpu_ids": -1,
#         "dataroot": "datasets/olracle/train"
#     },
#     "input_config_dir": "/opt/ml/input/config",
#     "input_data_config": {},
#     "input_dir": "/opt/ml/input",
#     "is_master": true,
#     "job_name": "pytorch-training-2020-11-16-14-35-15-609",
#     "log_level": 20,
#     "master_hostname": "algo-1",
#     "model_dir": "/opt/ml/model",
#     "module_dir": "s3://sagemaker-eu-central-1-213183576773/pytorch-training-2020-11-16-14-35-15-609/source/sourcedir.tar.gz",
#     "module_name": "train",
#     "network_interface_name": "eth0",
#     "num_cpus": 4,
#     "num_gpus": 0,
#     "output_data_dir": "/opt/ml/output/data",
#     "output_dir": "/opt/ml/output",
#     "output_intermediate_dir": "/opt/ml/output/intermediate",
#     "resource_config": {
#         "current_host": "algo-1",
#         "hosts": [
#             "algo-1"
#         ],
#         "network_interface_name": "eth0"
#     },
#     "user_entry_point": "train.py"
# }
#
# Environment variables:
#
# SM_HOSTS=["algo-1"]
# SM_NETWORK_INTERFACE_NAME=eth0
# SM_HPS={"batch_size":60,"checkpoints_dir":"checkpoints","dataroot":"datasets/olracle/train","dataset_mode":"aligned","gpu_ids":-1,"lr":0.005,"model":"pix2pix","n_epochs":1,"n_epochs_decay":0,"name":"olracle-pix2pix","print_freq":2}
# SM_USER_ENTRY_POINT=train.py
# SM_FRAMEWORK_PARAMS={}
# SM_RESOURCE_CONFIG={"current_host":"algo-1","hosts":["algo-1"],"network_interface_name":"eth0"}
# SM_INPUT_DATA_CONFIG={}
# SM_OUTPUT_DATA_DIR=/opt/ml/output/data
# SM_CHANNELS=[]
# SM_CURRENT_HOST=algo-1
# SM_MODULE_NAME=train
# SM_LOG_LEVEL=20
# SM_FRAMEWORK_MODULE=sagemaker_pytorch_container.training:main
# SM_INPUT_DIR=/opt/ml/input
# SM_INPUT_CONFIG_DIR=/opt/ml/input/config
# SM_OUTPUT_DIR=/opt/ml/output
# SM_NUM_CPUS=4
# SM_NUM_GPUS=0
# SM_MODEL_DIR=/opt/ml/model
# SM_MODULE_DIR=s3://sagemaker-eu-central-1-213183576773/pytorch-training-2020-11-16-14-35-15-609/source/sourcedir.tar.gz
# SM_TRAINING_ENV={"additional_framework_parameters":{},"channel_input_dirs":{},"current_host":"algo-1","framework_module":"sagemaker_pytorch_container.training:main","hosts":["algo-1"],"hyperparameters":{"batch_size":60,"checkpoints_dir":"checkpoints","dataroot":"datasets/olracle/train","dataset_mode":"aligned","gpu_ids":-1,"lr":0.005,"model":"pix2pix","n_epochs":1,"n_epochs_decay":0,"name":"olracle-pix2pix","print_freq":2},"input_config_dir":"/opt/ml/input/config","input_data_config":{},"input_dir":"/opt/ml/input","is_master":true,"job_name":"pytorch-training-2020-11-16-14-35-15-609","log_level":20,"master_hostname":"algo-1","model_dir":"/opt/ml/model","module_dir":"s3://sagemaker-eu-central-1-213183576773/pytorch-training-2020-11-16-14-35-15-609/source/sourcedir.tar.gz","module_name":"train","network_interface_name":"eth0","num_cpus":4,"num_gpus":0,"output_data_dir":"/opt/ml/output/data","output_dir":"/opt/ml/output","output_intermediate_dir":"/opt/ml/output/intermediate","resource_config":{"current_host":"algo-1","hosts":["algo-1"],"network_interface_name":"eth0"},"user_entry_point":"train.py"}
# SM_USER_ARGS=["--batch_size","60","--checkpoints_dir","checkpoints","--dataroot","datasets/olracle/train","--dataset_mode","aligned","--gpu_ids","-1","--lr","0.005","--model","pix2pix","--n_epochs","1","--n_epochs_decay","0","--name","olracle-pix2pix","--print_freq","2"]
# SM_OUTPUT_INTERMEDIATE_DIR=/opt/ml/output/intermediate
# SM_HP_CHECKPOINTS_DIR=checkpoints
# SM_HP_BATCH_SIZE=60
# SM_HP_N_EPOCHS_DECAY=0
# SM_HP_LR=0.005
# SM_HP_PRINT_FREQ=2
# SM_HP_N_EPOCHS=1
# SM_HP_DATASET_MODE=aligned
# SM_HP_NAME=olracle-pix2pix
# SM_HP_MODEL=pix2pix
# SM_HP_GPU_IDS=-1
# SM_HP_DATAROOT=datasets/olracle/train
# PYTHONPATH=/opt/ml/code:/opt/conda/bin:/opt/conda/lib/python36.zip:/opt/conda/lib/python3.6:/opt/conda/lib/python3.6/lib-dynload:/opt/conda/lib/python3.6/site-packages
#
# Invoking script with the following command:
#
# /opt/conda/bin/python train.py --batch_size 60 --checkpoints_dir checkpoints --dataroot datasets/olracle/train --dataset_mode aligned --gpu_ids -1 --lr 0.005 --model pix2pix --n_epochs 1 --n_epochs_decay 0 --name olracle-pix2pix --print_freq 2
#
#
#
# 2020-11-16 14:38:20 Training - Training image download completed. Training in progress.----------------- Options ---------------
#                batch_size: 60                            #011[default: 1]
#                     beta1: 0.5
#           checkpoints_dir: checkpoints                   #011[default: ./checkpoints]
#            continue_train: False
#                 crop_size: 256
#                  dataroot: datasets/olracle/train        #011[default: None]
#              dataset_mode: aligned
#                 direction: AtoB
#               display_env: main
#              display_freq: 400
#                display_id: 1
#             display_ncols: 4
#              display_port: 8097
#            display_server: http://localhost
#           display_winsize: 256
#                     epoch: latest
#               epoch_count: 1
#                  gan_mode: vanilla
#                   gpu_ids: -1                            #011[default: 0]
#                 init_gain: 0.02
#                 init_type: normal
#                  input_nc: 3
#                   isTrain: True                          #011[default: None]
#                 lambda_L1: 100.0
#                 load_iter: 0                             #011[default: 0]
#                 load_size: 286
#                        lr: 0.005                         #011[default: 0.0002]
#            lr_decay_iters: 50
#                 lr_policy: linear
#          max_dataset_size: inf
#                     model: pix2pix                       #011[default: cycle_gan]
#                  n_epochs: 1                             #011[default: 100]
#            n_epochs_decay: 0                             #011[default: 100]
#                n_layers_D: 3
#                      name: olracle-pix2pix               #011[default: experiment_name]
#                       ndf: 64
#                      netD: basic
#                      netG: unet_256
#                       ngf: 64
#                no_dropout: False
#                   no_flip: False
#                   no_html: False
#                      norm: batch
#               num_threads: 4
#                 output_nc: 3
#                     phase: train
#                 pool_size: 0
#                preprocess: resize_and_crop
#                print_freq: 2                             #011[default: 100]
#              save_by_iter: False
#           save_epoch_freq: 5
#          save_latest_freq: 5000
#            serial_batches: False
#                    suffix:
#          update_html_freq: 1000
#                   verbose: False
# ----------------- End -------------------
# dataset [AlignedDataset] was created
# The number of training images = 120
# initialize network with normal
# initialize network with normal
# model [Pix2PixModel] was created
# ---------- Networks initialized -------------
# [Network G] Total number of parameters : 54.414 M
# [Network D] Total number of parameters : 2.769 M
# -----------------------------------------------
# Exception in user code:
# ------------------------------------------------------------
# Could not connect to Visdom server.
#  Trying to start a server....
# Command: /opt/conda/bin/python -m visdom.server -p 8097 &>/dev/null &
# create web directory checkpoints/olracle-pix2pix/web...
# [2020-11-16 14:38:47.869 algo-1:71 INFO json_config.py:90] Creating hook from json_config at /opt/ml/input/config/debughookconfig.json.
# [2020-11-16 14:38:47.870 algo-1:71 INFO hook.py:183] tensorboard_dir has not been set for the hook. SMDebug will not be exporting tensorboard summaries.
# [2020-11-16 14:38:47.870 algo-1:71 INFO hook.py:228] Saving to /opt/ml/output/tensors
# [2020-11-16 14:38:47.872 algo-1:71 INFO hook.py:364] Monitoring the collections: losses
# [2020-11-16 14:38:47.873 algo-1:71 INFO hook.py:422] Hook is writing from the hook with pid: 71
#
# (epoch: 1, iters: 60, time: 1.005, data: 1.051) G_GAN: 0.794 G_L1: 90.461 D_real: 1.140 D_fake: 0.715
#
# 2020-11-16 14:40:48 Uploading - Uploading generated training model(epoch: 1, iters: 120, time: 0.977, data: 0.000) G_GAN: 8.462 G_L1: 50.240 D_real: 0.726 D_fake: 6.665
# End of epoch 1 / 1 #011 Time Taken: 119 sec
# learning rate = 0.0000000
# [2020-11-16 14:40:46.501 algo-1:71 INFO utils.py:25] The end of training job file will not be written for jobs running under SageMaker.
# 2020-11-16 14:40:46,817 sagemaker-containers INFO     Reporting training SUCCESS
#
# 2020-11-16 14:40:56 Completed - Training job completed
# Training seconds: 218
# Billable seconds: 218
# []
